# %%
import pandas as pd

# %%
  df = pd.read_excel(r'Superstore_USA.xlsx' , sheet_name = 'Orders')

# %%
 df1 =pd.read_excel(r'Superstore_USA.xlsx' , sheet_name = 'Returns')

# %%
df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
df1
# Out:
#       Order ID    Status
# 0           65  Returned
# 1          612  Returned
# 2          614  Returned
# 3          678  Returned
# 4          710  Returned
# ...        ...       ...
# 1629    182681  Returned
# 1630    182683  Returned
# 1631    182750  Returned
# 1632    182781  Returned
# 1633    182906  Returned
#
# [1634 rows x 2 columns]

# %%
q =df1[['Order ID' , 'Status']]

# %%
w = df[['Product Name' , 'Order ID']]

# %%
pd.merge(q,w,how = 'inner')
# Out:
#     Order ID    Status                                       Product Name
# 0        612  Returned                                         Xerox 1928
# 1        612  Returned                                               6190
# 2       4610  Returned  80 Minute Slim Jewel Case CD-R , 10/Pack - Sta...
# 3       4610  Returned         #10 White Business Envelopes,4 1/8 x 9 1/2
# 4       7079  Returned  Hon 2090 “Pillow Soft” Series Mid Back Swivel/...
# ..       ...       ...                                                ...
# 93     57638  Returned  Chromcraft Bull-Nose Wood Round Conference Tab...
# 94     57638  Returned       Personal Creations™ Ink Jet Cards and Labels
# 95     57638  Returned  Kleencut® Forged Office Shears by Acme United ...
# 96     59009  Returned                                          Xerox 197
# 97     59937  Returned                                          Xerox 197
#
# [98 rows x 3 columns]

# %%
ds = pd.merge(df,df1 , left_on = 'Order ID' ,right_on = 'Order ID' , how = 'inner')

# %%
 dr = pd.read_excel(r'Superstore_USA.xlsx' , sheet_name = 'Users')

# %%
len(df['Customer Name'].unique())
# Out:
# 2703

# %%
len(pd.DataFrame(df["Customer Name"].unique()))
# Out:
# 2703

# %%
s =pd.DataFrame(df['Ship Mode'])

# %%
r= (len(df[df['Ship Mode']=='Regular Air'])/len(s))*100

# %%
e = (len( df[df['Ship Mode']== 'Express Air'])/len(s))*100

# %%
df['Ship Mode'].unique()
# Out:
# array(['Regular Air', 'Express Air', 'Delivery Truck'], dtype=object)

# %%
d = (len(df[df['Ship Mode'] == 'Delivery Truck'])/len(s))*100

# %%
print('for mode regular air' ,":",r,"%" , "\n""for mode Express air :" , e,"%", "\n""for mode Delivery Truck :",d,"%" )
# Out:
# for mode regular air : 74.64460004243581 %
# for mode Express air : 11.744112030553786 %
# for mode Delivery Truck : 13.611287927010396 %

# %%
df['conv_order_date']= pd.to_datetime(df['Order Date'])

# %%
df['con_ship_date'] = pd.DataFrame(df['Ship Date'])

# %%
df['delivery_time'] = pd.DataFrame( df['conv_order_date'] - df['con_ship_date'])

# %%
df.groupby(df['conv_order_date'] - df['con_ship_date'])['Order ID']

# %%
df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
sd = df[['delivery_time' , 'Order ID']]

# %%
sd[sd['delivery_time'] == sum(sd['delivery_time'])]['Order ID']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [192], in <cell line: 1>()
# ----> 1 sd[sd['delivery_time'] == sum(sd['delivery_time'])]['Order ID']
#
# TypeError: unsupported operand type(s) for +: 'int' and 'Timedelta'

# %%
sum['delivery_time']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [199], in <cell line: 1>()
# ----> 1 sum['delivery_time']
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
sd[sd['delivery_time'] == sum(sd['delivery_time'])]['Order ID']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [200], in <cell line: 1>()
# ----> 1 sd[sd['delivery_time'] == sum(sd['delivery_time'])]['Order ID']
#
# TypeError: unsupported operand type(s) for +: 'int' and 'Timedelta'

# %%
sd['delivery_time'] = sd['delivery_time'].astype(str)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_1160\627138460.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sd['delivery_time'] = sd['delivery_time'].astype(str)

# %%
sd.dtypes
# Out:
# delivery_time    object
# Order ID          int64
# dtype: object

# %%
sd['delivery_time'] = sd['delivery_time'].str.replace('days' , '')
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_1160\382127981.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sd['delivery_time'] = sd['delivery_time'].str.replace('days' , '')

# %%
sd
# Out:
#      delivery_time  Order ID
# 0              -2      88525
# 1              -1      88522
# 2              -1      88523
# 3              -1      88523
# 4               0      88523
# ...            ...       ...
# 9421           -1      87532
# 9422            0      87532
# 9423           -2      87533
# 9424           -3      87530
# 9425           -2      87533
#
# [9426 rows x 2 columns]

# %%
sd['delivery_time'] = sd['delivery_time'].astype(int)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_1160\1207822710.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sd['delivery_time'] = sd['delivery_time'].astype(int)

# %%
sd['delivery_time'] == sum('delivery_time')['Order ID']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [209], in <cell line: 1>()
# ----> 1 sd['delivery_time'] == sum('delivery_time')['Order ID']
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
c
# Out:
#       delivery_time
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# ...             ...
# 9421          False
# 9422          False
# 9423          False
# 9424          False
# 9425          False
#
# [9426 rows x 1 columns]

# %%
sd[sd['delivery_time'] < -10]
# Out:
#       delivery_time  Order ID
# 643             -84     87215
# 1548            -11     86318
# 1549            -15     86318
# 1678            -17     87957
# 1679            -11     87957
# 1680            -28     87957
# 1697            -17     19556
# 1698            -11     19556
# 1699            -28     19556
# 2515            -92     86177
# 5548            -14     88223
# 5673            -17     88352
# 5859            -22     87572
# 5881            -24     91294
# 8607            -18     86434
# 8609            -17     86436
# 8610            -19     86436
# 8973            -19     87300
# 8982            -27     19841
# 8983            -31     19841
# 8993            -19     19841
# 8996            -27     87300
# 8997            -31     87300

# %%
sd
# Out:
#       delivery_time  Order ID
# 0                -2     88525
# 1                -1     88522
# 2                -1     88523
# 3                -1     88523
# 4                 0     88523
# ...             ...       ...
# 9421             -1     87532
# 9422              0     87532
# 9423             -2     87533
# 9424             -3     87530
# 9425             -2     87533
#
# [9426 rows x 2 columns]

# %%
pd.merge(dr,ds , left_on = 'Region' , right_on = 'Region' , how = 'inner')
# Out:
#      Region  Manager  Row ID Order Priority  Discount  Unit Price  \
# 0   Central    Chris    3435       Critical      0.03        5.34
# 1   Central    Chris    7659       Critical      0.06        5.98
# 2   Central    Chris    7660       Critical      0.06       12.44
# 3   Central    Chris    4697           High      0.08       10.35
# 4   Central    Chris    7106           High      0.04      304.99
# ..      ...      ...     ...            ...       ...         ...
# 93     West  William    4628            Low      0.08       12.44
# 94     West  William     985  Not Specified      0.02       54.20
# 95     West  William     986  Not Specified      0.06       37.94
# 96     West  William     987  Not Specified      0.10       55.29
# 97     West  William    6041         Medium      0.05        4.28
#
#     Shipping Cost  Customer ID         Customer Name    Ship Mode  ...  \
# 0            5.63         1106  Maxine Collier Grady  Regular Air  ...
# ...

# %%
rm
# Out:
#      Region  Manager  Row ID Order Priority  Discount  Unit Price  \
# 0   Central    Chris    3435       Critical      0.03        5.34
# 1   Central    Chris    7659       Critical      0.06        5.98
# 2   Central    Chris    7660       Critical      0.06       12.44
# 3   Central    Chris    4697           High      0.08       10.35
# 4   Central    Chris    7106           High      0.04      304.99
# ..      ...      ...     ...            ...       ...         ...
# 93     West  William    4628            Low      0.08       12.44
# 94     West  William     985  Not Specified      0.02       54.20
# 95     West  William     986  Not Specified      0.06       37.94
# 96     West  William     987  Not Specified      0.10       55.29
# 97     West  William    6041         Medium      0.05        4.28
#
#     Shipping Cost  Customer ID         Customer Name    Ship Mode  ...  \
# 0            5.63         1106  Maxine Collier Grady  Regular Air  ...
# ...

# %%
rm['delivery_time'] = rm['delivery_time'].astype(str)

# %%
rm['delivery_time'] = rm['delivery_time'].str.replace('days' , '')

# %%
rm['delivery_time'] = rm['delivery_time'].astype(int)

# %%
rm[rm['delivery_time']<-10]
# Out:
# Empty DataFrame
# Columns: [Region, Manager, Row ID, Order Priority, Discount, Unit Price, Shipping Cost, Customer ID, Customer Name, Ship Mode, Customer Segment, Product Category, Product Sub-Category, Product Container, Product Name, Product Base Margin, State or Province, City, Postal Code, Order Date, Ship Date, Profit, Quantity ordered new, Sales, Order ID, conv_order_date, con_ship_date, delivery_time, Status]
# Index: []
#
# [0 rows x 29 columns]

# %%
len(rm)
# Out:
# 98

# %%
rm[rm['delivery_time' , 'Region' , 'Manager' , 'Order ID']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('delivery_time', 'Region', 'Manager', 'Order ID')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
rm.groupby(['delivery_time' , 'Region'])['Manager']

# %%
rm[['delivery_time' , 'Region' , 'Manager', 'Order ID']]
# Out:
#     delivery_time   Region  Manager  Order ID
# 0              -1  Central    Chris     24519
# 1              -1  Central    Chris     54914
# 2              -2  Central    Chris     54914
# 3              -2  Central    Chris     33477
# 4              -2  Central    Chris     50721
# ..            ...      ...      ...       ...
# 93             -5     West  William     32931
# 94              0     West  William      7107
# 95             -2     West  William      7107
# 96             -1     West  William      7107
# 97             -2     West  William     42823
#
# [98 rows x 4 columns]

# %%
rm['delivery_time'] == sum(rm['delivery_time'])['Region']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [287], in <cell line: 1>()
# ----> 1 rm['delivery_time'] == sum(rm['delivery_time'])['Region']
#
# TypeError: 'int' object is not subscriptable

# %%
rm
# Out:
#      Region  Manager  Row ID Order Priority  Discount  Unit Price  \
# 0   Central    Chris    3435       Critical      0.03        5.34
# 1   Central    Chris    7659       Critical      0.06        5.98
# 2   Central    Chris    7660       Critical      0.06       12.44
# 3   Central    Chris    4697           High      0.08       10.35
# 4   Central    Chris    7106           High      0.04      304.99
# ..      ...      ...     ...            ...       ...         ...
# 93     West  William    4628            Low      0.08       12.44
# 94     West  William     985  Not Specified      0.02       54.20
# 95     West  William     986  Not Specified      0.06       37.94
# 96     West  William     987  Not Specified      0.10       55.29
# 97     West  William    6041         Medium      0.05        4.28
#
#     Shipping Cost  Customer ID         Customer Name    Ship Mode  ...  \
# 0            5.63         1106  Maxine Collier Grady  Regular Air  ...
# ...

# %%
rm[rm['delivery_time'] < -10]
# Out:
# Empty DataFrame
# Columns: [Region, Manager, Row ID, Order Priority, Discount, Unit Price, Shipping Cost, Customer ID, Customer Name, Ship Mode, Customer Segment, Product Category, Product Sub-Category, Product Container, Product Name, Product Base Margin, State or Province, City, Postal Code, Order Date, Ship Date, Profit, Quantity ordered new, Sales, Order ID, conv_order_date, con_ship_date, delivery_time, Status]
# Index: []
#
# [0 rows x 29 columns]

# %%
df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
df['delivery_time']= df['delivery_time'].astype(str)

# %%
df['delivery_time']= df['delivery_time'].str.replace('days' , '')

# %%
df['delivery_time']= df['delivery_time'].astype(int)

# %%
df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
df2 = pd.merge(df , dr , how = 'inner')

# %%
df3 =pd.merge(df2 , df1 , how = 'inner')

# %%
df3[df3['delivery_time'] > -10]
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0     3435       Critical      0.03        5.34           5.63         1106
# 1     7659       Critical      0.06        5.98           5.46         1106
# 2     7660       Critical      0.06       12.44           6.27         1106
# 3     4697           High      0.08       10.35           0.99         1106
# 4     7106           High      0.04      304.99          19.99         1630
# ..     ...            ...       ...         ...            ...          ...
# 93    5257            Low      0.09      550.98          64.59          349
# 94    6643       Critical      0.02        5.98           5.46          349
# 95    7966           High      0.05        7.99           5.03         1060
# 96    1952       Critical      0.05       70.71          37.58         1959
# 97    8251       Critical      0.02       30.98          17.08         2882
#
# ...

# %%
df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
df3
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0     3435       Critical      0.03        5.34           5.63         1106
# 1     7659       Critical      0.06        5.98           5.46         1106
# 2     7660       Critical      0.06       12.44           6.27         1106
# 3     4697           High      0.08       10.35           0.99         1106
# 4     7106           High      0.04      304.99          19.99         1630
# ..     ...            ...       ...         ...            ...          ...
# 93    5257            Low      0.09      550.98          64.59          349
# 94    6643       Critical      0.02        5.98           5.46          349
# 95    7966           High      0.05        7.99           5.03         1060
# 96    1952       Critical      0.05       70.71          37.58         1959
# 97    8251       Critical      0.02       30.98          17.08         2882
#
# ...

# %%
df2
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      24844         Medium      0.09       78.69          19.99           14
# 2      24846         Medium      0.08        3.28           2.31           14
# 3      24847         Medium      0.05        3.28           4.20           14
# 4      24848         Medium      0.05        3.58           1.63           14
# ...      ...            ...       ...         ...            ...          ...
# 9421   25689       Critical      0.10        4.98           4.70         3381
# 9422   26152  Not Specified      0.00       58.14          36.61         3382
# 9423   26153  Not Specified      0.00       29.99           5.50         3382
# 9424   26154  Not Specified      0.03       16.16           7.74         3382
# 9425   26140  Not Specified      0.04        5.98           7.15         3382
#
# ...

# %%
df2.groupby(['Region'])['Profit'].sum()
# Out:
# Region
# Central    519825.567067
# East       377566.186045
# South      104201.192420
# West       310849.453897
# Name: Profit, dtype: float64

# %%
df2.dtypes
# Out:
# Row ID                           int64
# Order Priority                  object
# Discount                       float64
# Unit Price                     float64
# Shipping Cost                  float64
# Customer ID                      int64
# Customer Name                   object
# Ship Mode                       object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Container               object
# Product Name                    object
# Product Base Margin            float64
# Region                          object
# State or Province               object
# City                            object
# Postal Code                      int64
# Order Date              datetime64[ns]
# Ship Date               datetime64[ns]
# Profit                         float64
# Quantity ordered new             int64
# Sales                          float64
# Order ID                         int64
# ...

# %%
State or Province

# %%
 l =pd.DataFrame(df2.groupby(['State or Province'])['Discount'].sum().reset_index())

# %%
l[l['Discount'] == max(l['Discount'])]
# Out:
#   State or Province  Discount
# 3        California     52.28

# %%
df2['Postal Code'].unique()
# Out:
# array([60101, 55372, 68005, ..., 30144, 30240, 31204], dtype=int64)

# %%
df2.groupby(['Customer Segment'])['Profit'].sum()
# Out:
# Customer Segment
# Consumer          206559.625348
# Corporate         505538.627783
# Home Office       283869.553814
# Small Business    316474.592482
# Name: Profit, dtype: float64

# %%
 h = df2[['Product Sub-Category', 'Profit']].groupby('Product Sub-Category').sum().reset_index()

# %%
h
# Out:
#               Product Sub-Category         Profit
# 0                       Appliances  121651.391380
# 1   Binders and Binder Accessories  226572.523042
# 2                        Bookcases   -7708.748564
# 3               Chairs & Chairmats  165348.882760
# 4             Computer Peripherals   87917.842513
# 5                  Copiers and Fax  129156.684030
# 6                        Envelopes   46133.223840
# 7                           Labels   17775.320505
# 8               Office Furnishings   92209.225867
# 9                  Office Machines  168072.833340
# 10                           Paper   35361.621738
# 11             Pens & Art Supplies    1195.902840
# 12                    Rubber Bands   -2841.722459
# 13   Scissors, Rulers and Trimmers   -1936.849120
# 14          Storage & Organization    8078.804727
# 15                          Tables  -72495.061875
# 16    Telephones and Communication  297950.524866

# %%
x = h.sort_values(by ='Profit' , ascending = False , ignore_index =True)

# %%
x['Product Sub-Category'][9]
# Out:
# 'Paper'

# %%
df2['loss_product'] = df2['Unit Price'] + df2['Shipping Cost']

# %%
df2
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      24844         Medium      0.09       78.69          19.99           14
# 2      24846         Medium      0.08        3.28           2.31           14
# 3      24847         Medium      0.05        3.28           4.20           14
# 4      24848         Medium      0.05        3.58           1.63           14
# ...      ...            ...       ...         ...            ...          ...
# 9421   25689       Critical      0.10        4.98           4.70         3381
# 9422   26152  Not Specified      0.00       58.14          36.61         3382
# 9423   26153  Not Specified      0.00       29.99           5.50         3382
# 9424   26154  Not Specified      0.03       16.16           7.74         3382
# 9425   26140  Not Specified      0.04        5.98           7.15         3382
#
# ...

# %%
 n =df2[['loss_product', 'Product Sub-Category']].groupby('Product Sub-Category').sum().reset_index()

# %%
j = n.sort_values(by = 'loss_product' , ascending = True , ignore_index= True)

# %%
j['Product Sub-Category'][9]
# Out:
# 'Bookcases'

# %%
pd.DataFrame(df2.groupby(['Product Name'])['Product Base Margin'].sum())
# Out:
#                                                     Product Base Margin
# Product Name
# "While you Were Out" Message Book, One Form per...                 2.10
# #10 Self-Seal White Envelopes                                      1.80
# #10 White Business Envelopes,4 1/8 x 9 1/2                         5.32
# #10- 4 1/8" x 9 1/2" Recycled Envelopes                            6.84
# #10- 4 1/8" x 9 1/2" Security-Tint Envelopes                       3.24
# ...                                                                 ...
# i500plus                                                           1.16
# i600                                                               1.68
# iDEN i550                                                          1.20
# iDEN i95                                                           2.36
# iDENi80s                                                           2.95
#
# [1263 rows x 1 columns]

# %%
 z =df2[['Product Base Margin' ,'Product Name' ]].groupby('Product Name').sum().reset_index()

# %%
Product Base Margin

# %%
 p = z.sort_values(by = 'Product Base Margin' , ascending = False , ignore_index =  True)

# %%
p['Product Name'][10]
# Out:
# 'Serrated Blade or Curved Handle Hand Letter Openers'

# %%
p
# Out:
#                                            Product Name  Product Base Margin
# 0             Global High-Back Leather Tilter, Burgundy                19.98
# 1     BoxOffice By Design Rectangular and Half-Moon ...                18.33
# 2                       Bevis 36 x 72 Conference Tables                16.38
# 3                  Adesso Programmable 142-Key Keyboard                15.45
# 4                                           Accessory36                14.11
# ...                                                 ...                  ...
# 1258  SAFCO Optional Arm Kit for Workspace® Cribbage...                 0.00
# 1259  SAFCO PlanMaster Heigh-Adjustable Drafting Tab...                 0.00
# 1260  Safco Value Mate Steel Bookcase, Baked Enamel ...                 0.00
# 1261                    Safco Contoured Stacking Chairs                 0.00
# 1262                      SAFCO Boltless Steel Shelving                 0.00
#
# [1263 rows x 2 columns]
